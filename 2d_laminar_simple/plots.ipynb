# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %matplotlib inline
plt.rcParams['figure.dpi'] = 200
plt.rcParams['savefig.dpi'] = 200
plt.rcParams["figure.figsize"] = (6,4)

from labellines import labelLines

# %%
from fieldsValues import case

import postCodes.cf_cp_wall as coef
import postCodes.residuals as residuals

# %% [markdown]
# ## Residuals

# %%
data_res = residuals.get_residuals()

# %%
plt.plot(data_res['Ux'], linewidth=0.5, label='Ux', c='r')
plt.plot(data_res['Uy'], linewidth=0.5, label='Uy', c='b')
plt.plot(data_res['p'], linewidth=0.5, label='p', c='g')

plt.legend()
plt.grid()
plt.yscale('log')

# %% [markdown]
# ## cf

# %%
cf_lower,cf_upper = coef.get_cf(case)

# %%
plt.plot(cf_lower['x']/case.h,cf_lower['cf'], c='b')
plt.grid()
plt.xlabel('x/h')
plt.ylabel('cf')
# Out:
# Text(0, 0.5, 'cf')

# %%
plt.plot(cf_upper['x']/case.h,cf_upper['cf'], c='b')
plt.grid()
plt.xlabel('x/h')
plt.ylabel('cf')
# Out:
# Text(0, 0.5, 'cf')

# %% [markdown]
# ## cp

# %%
cp_lower,cp_upper = coef.get_cp(case)

# %%
plt.plot(cp_lower['x']/case.h,cp_lower['cp'], c='b')
plt.grid()
plt.xlabel('x/h')
plt.ylabel('cp')
# Out:
# Text(0, 0.5, 'cp')

# %%
plt.plot(cp_upper['x']/case.h,cp_upper['cp'], c='b')
plt.grid()
plt.xlabel('x/h')
plt.ylabel('cp')
# Out:
# Text(0, 0.5, 'cp')

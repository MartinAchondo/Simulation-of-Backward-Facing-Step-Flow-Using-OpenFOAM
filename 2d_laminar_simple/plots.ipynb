# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %matplotlib inline
plt.rcParams['figure.dpi'] = 200
plt.rcParams['savefig.dpi'] = 200
plt.rcParams["figure.figsize"] = (6,4)

from labellines import labelLines

# %%
from fieldsValues import case

import postCodes.cf_cp_wall as coef
import postCodes.residuals as residuals
import postCodes.U_p_profile as profile

# %% [markdown]
# ## Residuals

# %%
data_res = residuals.get_residuals('residuals.dat','0')

# %%
plt.plot(data_res['Ux'], linewidth=0.5, label='Ux', c='r')
plt.plot(data_res['Uy'], linewidth=0.5, label='Uy', c='b')
plt.plot(data_res['p'], linewidth=0.5, label='p', c='g')

plt.legend()
plt.grid()
plt.yscale('log')

# %%
case.endTime = 3000

# %% [markdown]
# ## cf

# %%
cf_lower,cf_upper = coef.get_cf(case)

# %%
plt.plot(cf_lower['x']/case.h-10,cf_lower['cf'], c='b')
plt.grid()
plt.xlabel('x/h')
plt.ylabel('cf')
# Out:
# Text(0, 0.5, 'cf')

# %%
plt.plot(cf_upper['x']/case.h-10,cf_upper['cf'], c='b')
plt.grid()
plt.xlabel('x/h')
plt.ylabel('cf')
# Out:
# Text(0, 0.5, 'cf')

# %% [markdown]
# ## cp

# %%
cp_lower,cp_upper = coef.get_cp(case)

# %%
plt.plot(cp_lower['x']/case.h-10,cp_lower['cp'], c='b')
plt.grid()
plt.xlabel('x/h')
plt.ylabel('cp')
# Out:
# Text(0, 0.5, 'cp')

# %%
plt.plot(cp_upper['x']/case.h-10,cp_upper['cp'], c='b')
plt.grid()
plt.xlabel('x/h')
plt.ylabel('cp')
# Out:
# Text(0, 0.5, 'cp')

# %% [markdown]
# ## Profile

# %%
case.endTime = 479

# %%
f, (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8) = plt.subplots(1, 8, sharey=True, sharex=True)

L_ax = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8]

for i in range(8):
    i += 1
    U_df = profile.get_profile(f'X{i}','U',case)
    L_ax[i-1].plot(U_df['Ux']*100,U_df['y'], c='r')
    L_ax[i-1].grid()

ax1.set_ylabel('y [mm]')
ax4.set_xlabel(r'U [m/s] *$10^{-4}$')
# Out:
# Text(0.5, 0, 'U [m/s] *$10^{-4}$')

# %%
f, (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8) = plt.subplots(1, 8, sharey=True, sharex=True)

L_ax = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8]

for i in range(8):
    i += 1
    p_df = profile.get_profile(f'X{i}','p',case)
    L_ax[i-1].plot(p_df['p']*10**8,p_df['y'], c='b')
    L_ax[i-1].grid()

ax1.set_ylabel('y [mm]')
ax4.set_xlabel(r'p [Pa] *$10^{-8}$')
# Out:
# Text(0.5, 0, 'p [Pa] *$10^{-8}$')
